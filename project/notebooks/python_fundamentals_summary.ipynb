# %% [markdown]
# # Python Fundamentals Summary
#
# A small reproducible demonstration of Python, NumPy, pandas, and a reusable project utility before working with market data.

# %%
from pathlib import Path
import sys
import numpy as np
import pandas as pd

ROOT = Path.cwd()

if ROOT.name == "notebooks":
    ROOT = ROOT.parent

if (ROOT / "project").exists():
    ROOT = ROOT / "project"

if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from src.utils import clean_column_names

values = np.array([1, 2, 3, 4, 5])

print("Sum:", values.sum())
print("Mean:", values.mean())

demo = pd.DataFrame({
    "Sector Name": ["Energy", "Health Care"],
    "Return": [0.08, 0.05],
})

clean_column_names(demo)
# Out:
# Sum: 15
# Mean: 3.0
#    sector_name  return
# 0       Energy    0.08
# 1  Health Care    0.05

# %%
summary = pd.DataFrame({
    'sector': ['Energy', 'Health Care', 'Energy'],
    'return': [0.08, 0.05, -0.02]
}).groupby('sector')['return'].agg(['mean', 'std'])
summary
# Out:
#              mean       std
# sector
# Energy       0.03  0.070711
# Health Care  0.05       NaN
