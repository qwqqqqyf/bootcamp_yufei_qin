# %% [markdown]
# # Setup: Generate Sample Dataset
#
# This cell creates the required folder structure (`data/raw/` and `data/processed/`) relative to the notebook, and generates the sample CSV dataset with missing values.
# This ensures the dataset is ready for cleaning functions and saves it to `data/raw/sample_data.csv`.

# %%
# --- files this notebook needs (run me first - I only report, I change nothing) ---
from pathlib import Path

ROOT = Path.cwd()          # notebooks are meant to be run from their own folder
CHECKS = [
    ("src/cleaning.py", "NEEDED", "YOU write this in the homework - the import fails until you do"),
]

print(f"Looking in: {ROOT}\n")
missing = 0
for rel, kind, note in CHECKS:
    here = (ROOT / rel).exists()
    if not here and kind == "NEEDED":
        missing += 1
    print(f"  [{'OK ' if here else 'MISS'}]  {kind:<8}  {rel:<34}  {note}")

if missing:
    print(f"\n{missing} needed file(s) missing. Put them at the paths above, relative to:\n  {ROOT}")
    print("If that folder looks wrong, you are running the notebook from the wrong place.")
else:
    print("\nAll needed files present.")
# Out:
# Looking in: c:\Users\qwqqqyf\bootcamp_yufei_qin\homework\homework06\notebooks
#
#   [MISS]  NEEDED    src/cleaning.py                     YOU write this in the homework - the import fails until you do
#
# 1 needed file(s) missing. Put them at the paths above, relative to:
#   c:\Users\qwqqqyf\bootcamp_yufei_qin\homework\homework06\notebooks
# If that folder looks wrong, you are running the notebook from the wrong place.

# %%
import os
import pandas as pd
import numpy as np

# Define folder paths relative to this notebook
raw_dir = 'data/raw'
processed_dir = 'data/processed'

# Create folders if they don't exist
os.makedirs(raw_dir, exist_ok=True)
os.makedirs(processed_dir, exist_ok=True)

# Define the sample data
data = {
    'age': [34, 45, 29, 50, 38, np.nan, 41],
    'income': [55000, np.nan, 42000, 58000, np.nan, np.nan, 49000],
    'score': [0.82, 0.91, np.nan, 0.76, 0.88, 0.65, 0.79],
    'zipcode': ['90210', '10001', '60614', '94103', '73301', '12345', '94105'],
    'city': ['Beverly', 'New York', 'Chicago', 'SF', 'Austin', 'Unknown', 'San Francisco'],
    'extra_data': [np.nan, 42, np.nan, np.nan, np.nan, 5, np.nan]
}

# Create DataFrame
df = pd.DataFrame(data)

# Save to CSV in raw data folder
csv_path = os.path.join(raw_dir, 'sample_data.csv')
if not os.path.exists(csv_path):
    df.to_csv(csv_path, index=False)
    print(f'Sample dataset created and saved to {csv_path}')
else:
    print(f'File already exists at {csv_path}. Skipping CSV creation to avoid overwrite.')
# Out:
# Sample dataset created and saved to data/raw\sample_data.csv

# %% [markdown]
# # Homework Starter — Stage 6: Data Preprocessing
# Use this notebook to apply your cleaning functions and save processed data.

# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent))

from src import cleaning

# %%
import pandas as pd

# Uncomment once you have written src/cleaning.py (see the homework sheet).
# Until then this import fails - the module is yours to create.

# %% [markdown]
# ## Load Raw Dataset

# %%
df = pd.read_csv('data/raw/sample_data.csv')
df.head()
# Out:
#     age   income  score  zipcode      city  extra_data
# 0  34.0  55000.0   0.82    90210   Beverly         NaN
# 1  45.0      NaN   0.91    10001  New York        42.0
# 2  29.0  42000.0    NaN    60614   Chicago         NaN
# 3  50.0  58000.0   0.76    94103        SF         NaN
# 4  38.0      NaN   0.88    73301    Austin         NaN

# %%
print("Original shape:", df.shape)
print("\nMissing values:")
print(df.isna().sum())
# Out:
# Original shape: (7, 6)
#
# Missing values:
# age           1
# income        3
# score         1
# zipcode       0
# city          0
# extra_data    5
# dtype: int64

# %% [markdown]
# ## Apply Cleaning Functions

# %%
# TODO: Apply your functions here
df_clean = cleaning.fill_missing_median(
    df,
    ['age', 'income', 'score']
)

df_clean = cleaning.drop_missing(
    df_clean,
    threshold=0.5
)

df_clean = cleaning.normalize_data(
    df_clean,
    ['age', 'income', 'score']
)

df_clean.head()
# Out:
#         age  income     score  zipcode      city  extra_data
# 0  0.238095  0.8125  0.653846    90210   Beverly         NaN
# 1  0.761905  0.6250  1.000000    10001  New York        42.0
# 2  0.000000  0.0000  0.596154    60614   Chicago         NaN
# 3  1.000000  1.0000  0.423077    94103        SF         NaN
# 4  0.428571  0.6250  0.884615    73301    Austin         NaN

# %% [markdown]
# ## Original vs Cleaned Data
#
# The original dataset contains missing values in the numeric columns. Median imputation is used for numeric variables because it is simple and less sensitive to extreme values than mean imputation. Rows with excessive missing values are removed using a 50% non-missing threshold. Finally, numeric variables are normalized using min-max scaling so that their values fall between 0 and 1.

# %%
print("Original shape:", df.shape)
print("Cleaned shape:", df_clean.shape)

print("\nOriginal missing values:")
print(df.isna().sum())

print("\nCleaned missing values:")
print(df_clean.isna().sum())
# Out:
# Original shape: (7, 6)
# Cleaned shape: (7, 6)
#
# Original missing values:
# age           1
# income        3
# score         1
# zipcode       0
# city          0
# extra_data    5
# dtype: int64
#
# Cleaned missing values:
# age           0
# income        0
# score         0
# zipcode       0
# city          0
# extra_data    5
# dtype: int64

# %%
print(
    df_clean[['age', 'income', 'score']].describe()
)
# Out:
#             age    income     score
# count  7.000000  7.000000  7.000000
# mean   0.500000  0.589286  0.585165
# std    0.328479  0.314281  0.325952
# min    0.000000  0.000000  0.000000
# 25%    0.333333  0.531250  0.480769
# 50%    0.500000  0.625000  0.596154
# 75%    0.666667  0.718750  0.769231
# max    1.000000  1.000000  1.000000

# %% [markdown]
# ## Save Cleaned Dataset

# %%
output_path = 'data/processed/sample_data_cleaned.csv'

df_clean.to_csv(
    output_path,
    index=False
)

print(f"Cleaned dataset saved to {output_path}")
# Out:
# Cleaned dataset saved to data/processed/sample_data_cleaned.csv
